# %%
# imports

# data parsing and processing
import pandas as pd
import numpy as np
from utils import *

# knowlege graph
import networkx as nx
import matplotlib.pyplot as plt
import pandas as pd

# source paths
DATA_PATH = "../data/"

# %%
# class dataset(Dataset):
#         def __init__(self, data, tokenizer, max_len):
#             self.len = len(data)
#             self.sentences, self.labels, self.relations = zip(*data)
#             self.sentences = sentences
#             self.labels = labels
#             self.relations = relations
#             self.tokenizer = tokenizer
#             self.max_len = max_len

#         def __len__(self):
#           return self.len
            
#         def __getitem__(self, index):
#             sentence = self.sentences[index]
#             labels = self.labels[index]
#             relations = self.relations[index]
#             tokenized_sentence, labels = tokenize_and_preserve_labels(
#                 sentence, labels, self.tokenizer)
            
#             # add special tokens
#             tokenized_sentence = ["[CLS]"] + tokenized_sentence + ["[SEP]"]
            
#             # add Out of label tokens for special tokens
#             labels.insert(0, "O") 
#             labels.insert(-1, "O")
            
#             trunc = self.max_len
            
#             # truncate
#             if len(tokenized_sentence) > trunc:
#                 tokenized_sentence = tokenized_sentence[:trunc]
#                 labels = labels[:trunc]
#             else:
#                 # padding
#                 tokenized_sentence = tokenized_sentence + ["[PAD]" for _ in range(trunc - len(tokenized_sentence))]
#                 labels = labels + ["O" for _ in range(trunc - len(labels))]

#             attn_mask = [1 if token != "[PAD]" else 0 for token in tokenized_sentence]
#             ids = self.tokenizer.convert_tokens_to_ids(tokenized_sentence)
#             label_ids = [labels_to_ids[label] for label in labels]
            
#             return {
#                 "ids" : torch.tensor(ids, dtype=torch.long),
#                 "mask" : torch.tensor(attn_mask, dtype=torch.long),
#                 "targets" : torch.tensor(label_ids, dtype=torch.long)
#             }

# %% [markdown]
# # DDI

# %%
CORPORA_PATH = "raw/ddi-corpus/APIforDDICorpus/DDICorpus/"

# Preprocess training data
train_folder_drugbank = DATA_PATH + CORPORA_PATH + "Train/DrugBank/"
train_folder_medline = DATA_PATH + CORPORA_PATH + "Train/Medline/"
train_data = preprocess_data(train_folder_drugbank, train_folder_medline, parse_function = parse_ddi_xml)

# # Preprocess test data
test_folder_drugbank = DATA_PATH + CORPORA_PATH + "Test/Test for DrugNER task/DrugBank/"
test_folder_medline = DATA_PATH + CORPORA_PATH + "Test/Test for DrugNER task/MedLine/"

# Preprocess test data
test_data = preprocess_data(test_folder_drugbank, test_folder_medline, parse_function = parse_ddi_xml)
# # Split the data into training and validation sets (80% training, 20% validation)
train_data, val_data = create_train_val_split(train_data)
len(train_data), len(val_data), len(test_data)
# Out:
# (25013, 2779, 941)

# %%
# find some samples to check preprocessing functions
ddi_samples = []
multi_span_samples = []
for i, data in enumerate(train_data):
    if data['ddi']:
        ddi_samples.append(i)
    for ent in data['all_ents'].values():
        if len(ent['char_offset']) > 1:
            multi_span_samples.append(i)
            
len(ddi_samples), len(multi_span_samples)
# Out:
# (3588, 383)

# %%
len("b-k-g".split("-"))
# Out:
# 3

# %%
# edge cases
edge_cases = [sample for sample in ddi_samples if sample in multi_span_samples]
len(edge_cases)
# Out:
# 43

# %%
train_data[ddi_samples[1]]
# Out:
# {'filename': 'Enoxacin_ddi',
#  'sentence': 'Antacids containing aluminum hydroxide and magnesium hydroxide reduce the oral absorption of enoxacin by 75%.',
#  'sent_id': 'DDI-DrugBank.d395.s17',
#  'entity1': {'text': 'aluminum hydroxide',
#   'type': 'drug',
#   'char_offset': [(20, 37)]},
#  'entity2': {'text': 'enoxacin', 'type': 'drug', 'char_offset': [(93, 100)]},
#  'ddi': True,
#  'type': 'mechanism',
#  'all_ents': {'DDI-DrugBank.d395.s17.e0': {'text': 'Antacids',
#    'type': 'group',
#    'char_offset': [(0, 7)]},
#   'DDI-DrugBank.d395.s17.e1': {'text': 'aluminum hydroxide',
#    'type': 'drug',
#    'char_offset': [(20, 37)]},
#   'DDI-DrugBank.d395.s17.e2': {'text': 'magnesium hydroxide',
#    'type': 'drug',
#    'char_offset': [(43, 61)]},
#   'DDI-DrugBank.d395.s17.e3': {'text': 'enoxacin',
#    'type': 'drug',
#    'char_offset': [(93, 100)]}}}

# %%
example = edge_cases[2]

# %%
train_data[example]
# Out:
# {'filename': 'Echothiophate Iodide_ddi',
#  'sentence': 'Phospholine Iodide potentiates other cholinesterase inhibitors such as succinylcholine or organophosphate and carbamate insecticides.',
#  'sent_id': 'DDI-DrugBank.d377.s0',
#  'entity1': {'text': 'Phospholine Iodide',
#   'type': 'drug',
#   'char_offset': [(0, 17)]},
#  'entity2': {'text': 'cholinesterase inhibitors',
#   'type': 'group',
#   'char_offset': [(37, 61)]},
#  'ddi': True,
#  'type': 'effect',
#  'all_ents': {'DDI-DrugBank.d377.s0.e0': {'text': 'Phospholine Iodide',
#    'type': 'drug',
#    'char_offset': [(0, 17)]},
#   'DDI-DrugBank.d377.s0.e1': {'text': 'cholinesterase inhibitors',
#    'type': 'group',
#    'char_offset': [(37, 61)]},
#   'DDI-DrugBank.d377.s0.e2': {'text': 'succinylcholine',
#    'type': 'drug',
#    'char_offset': [(71, 85)]},
#   'DDI-DrugBank.d377.s0.e3': {'text': 'organophosphate insecticide',
#    'type': 'drug_n',
#    'char_offset': [(90, 104), (120, 130)]},
#   'DDI-DrugBank.d377.s0.e4': {'text': 'carbamate insecticide',
#    'type': 'drug_n',
#    'char_offset': [(110, 130)]}}}

# %%
extract_ner_data([train_data[example]])
# Out:
# [{'sentence': 'Phospholine Iodide potentiates other cholinesterase inhibitors such as succinylcholine or organophosphate and carbamate insecticides.',
#   'entities': [{'text': 'Phospholine Iodide',
#     'type': 'drug-effect',
#     'char_offset': [(0, 17)]},
#    {'text': 'cholinesterase inhibitors',
#     'type': 'group-effect',
#     'char_offset': [(37, 61)]},
#    {'text': 'succinylcholine', 'type': 'drug', 'char_offset': [(71, 85)]},
#    {'text': 'organophosphate insecticide',
#     'type': 'drug_n',
#     'char_offset': [(90, 104), (120, 130)]},
#    {'text': 'carbamate insecticide',
#     'type': 'drug_n',
#     'char_offset': [(110, 130)]}]}]

# %%
generate_conll_format_test(extract_ner_data([train_data[example]])[0])
# Out:
# {'tokens': ['Phospholine',
#   'Iodide',
#   'potentiates',
#   'other',
#   'cholinesterase',
#   'inhibitors',
#   'such',
#   'as',
#   'succinylcholine',
#   'or',
#   'organophosphate',
#   'and',
#   'carbamate',
#   'insecticides',
#   '.'],
#  'tags': ['B-drug-effect',
#   'I-drug-effect',
#   'O',
#   'O',
#   'B-group-effect',
#   'I-group-effect',
#   'O',
#   'O',
#   'B-drug',
#   'O',
#   'B-drug_n',
#   'O',
#   'B-drug_n',
#   'I-drug_n',
#   'O']}

# %%
conll, labels = generate_conll_format_test(extract_ner_data([train_data[example]])[0], return_labels=True)
chars = zip([char for char in train_data[example]['sentence']], labels)

# %%
width = 50
for token, tag in zip(conll['tokens'], conll['tags']):
    print("{:>{}} {:<{}}".format(token ,width, tag, width))
# Out:
#                                        Phospholine B-drug-effect
#                                             Iodide I-drug-effect
#                                        potentiates O
#                                              other O
#                                     cholinesterase B-group-effect
#                                         inhibitors I-group-effect
#                                               such O
#                                                 as O
#                                    succinylcholine B-drug
#                                                 or O
#                                    organophosphate B-drug_n
#                                                and O
#                                          carbamate B-drug_n
#                                       insecticides I-drug_n
#                                                  . O

# %%
for char, label in chars:
    print("{}{:>{}} {:<{}}".format(i, char ,width, label, width))
# Out:
# 133                                                 P B-drug-effect
# 133                                                 h I-drug-effect
# 133                                                 o I-drug-effect
# 133                                                 s I-drug-effect
# 133                                                 p I-drug-effect
# 133                                                 h I-drug-effect
# 133                                                 o I-drug-effect
# 133                                                 l I-drug-effect
# 133                                                 i I-drug-effect
# 133                                                 n I-drug-effect
# 133                                                 e I-drug-effect
# 133                                                   I-drug-effect
# 133                                                 I I-drug-effect
# 133                                                 o I-drug-effect
# 133                                                 d I-drug-effect
# 133                                                 i I-drug-effect
# 133                                                 d I-drug-effect
# 133                                                 e I-drug-effect
# 133                                                   O
# 133                                                 p O
# 133                                                 o O
# 133                                                 t O
# 133                                                 e O
# 133                                                 n O
# 133                                                 t O
# 133                                                 i O
# 133                                                 a O
# 133                                                 t O
# 133                                                 e O
# 133                                                 s O
# 133                                                   O
# 133                                                 o O
# 133                                                 t O
# 133                                                 h O
# 133                                                 e O
# 133                                                 r O
# 133                                                   O
# 133                                                 c B-group-effect
# 133                                                 h I-group-effect
# 133                                                 o I-group-effect
# 133                                                 l I-group-effect
# 133                                                 i I-group-effect
# 133                                                 n I-group-effect
# 133                                                 e I-group-effect
# 133                                                 s I-group-effect
# 133                                                 t I-group-effect
# 133                                                 e I-group-effect
# 133                                                 r I-group-effect
# 133                                                 a I-group-effect
# 133                                                 s I-group-effect
# 133                                                 e I-group-effect
# 133                                                   I-group-effect
# 133                                                 i I-group-effect
# 133                                                 n I-group-effect
# 133                                                 h I-group-effect
# 133                                                 i I-group-effect
# 133                                                 b I-group-effect
# 133                                                 i I-group-effect
# 133                                                 t I-group-effect
# 133                                                 o I-group-effect
# 133                                                 r I-group-effect
# 133                                                 s I-group-effect
# 133                                                   O
# 133                                                 s O
# 133                                                 u O
# 133                                                 c O
# 133                                                 h O
# 133                                                   O
# 133                                                 a O
# 133                                                 s O
# 133                                                   O
# 133                                                 s B-drug
# 133                                                 u I-drug
# 133                                                 c I-drug
# 133                                                 c I-drug
# 133                                                 i I-drug
# 133                                                 n I-drug
# 133                                                 y I-drug
# 133                                                 l I-drug
# 133                                                 c I-drug
# 133                                                 h I-drug
# 133                                                 o I-drug
# 133                                                 l I-drug
# 133                                                 i I-drug
# 133                                                 n I-drug
# 133                                                 e I-drug
# 133                                                   O
# 133                                                 o O
# 133                                                 r O
# 133                                                   O
# 133                                                 o B-drug_n
# 133                                                 r I-drug_n
# 133                                                 g I-drug_n
# 133                                                 a I-drug_n
# 133                                                 n I-drug_n
# 133                                                 o I-drug_n
# 133                                                 p I-drug_n
# 133                                                 h I-drug_n
# 133                                                 o I-drug_n
# 133                                                 s I-drug_n
# 133                                                 p I-drug_n
# 133                                                 h I-drug_n
# 133                                                 a I-drug_n
# 133                                                 t I-drug_n
# 133                                                 e I-drug_n
# 133                                                   O
# 133                                                 a O
# 133                                                 n O
# 133                                                 d O
# 133                                                   O
# 133                                                 c B-drug_n
# 133                                                 a I-drug_n
# 133                                                 r I-drug_n
# 133                                                 b I-drug_n
# 133                                                 a I-drug_n
# 133                                                 m I-drug_n
# 133                                                 a I-drug_n
# 133                                                 t I-drug_n
# 133                                                 e I-drug_n
# 133                                                   I-drug_n
# 133                                                 i I-drug_n
# 133                                                 n I-drug_n
# 133                                                 s I-drug_n
# 133                                                 e I-drug_n
# 133                                                 c I-drug_n
# 133                                                 t I-drug_n
# 133                                                 i I-drug_n
# 133                                                 c I-drug_n
# 133                                                 i I-drug_n
# 133                                                 d I-drug_n
# 133                                                 e I-drug_n
# 133                                                 s O
# 133                                                 . O

# %%
# Get NER Entities and put them in CoNLL format
conll_sents_train = []
ner_data_train = extract_ner_data(train_data)
for data in ner_data_train:
    conll_sents_train.append(generate_conll_format(data))
    
conll_sents_dev = []
ner_data_dev = extract_ner_data(val_data)
for data in ner_data_dev:
    conll_sents_dev.append(generate_conll_format(data))
    
conll_sents_test = []
ner_data_test = extract_ner_data(test_data)
for data in ner_data_test:
    conll_sents_test.append(generate_conll_format(data))

# %%
from transformers import AutoTokenizer
tokenizer = AutoTokenizer.from_pretrained('allenai/scibert_scivocab_uncased')

sample = conll_sents_train[example]
tokens_tags = zip(sample['tokens'], sample['tags'])
tokenized_tokens, tokenized_tags = tokenize_and_preserve_labels(sample['tokens'], sample['tags'], tokenizer=tokenizer, max_length = 70)
tokenized_tokens_tags = zip(tokenized_tokens, tokenized_tags)

# %%
for token, tag in tokens_tags:
    print("{:>{}} {:<{}}".format(token ,width, tag, width))
# Out:
#                                        Phospholine B-drug-effect
#                                             Iodide I-drug-effect
#                                        potentiates O
#                                              other O
#                                     cholinesterase B-group-effect
#                                         inhibitors I-group-effect
#                                               such O
#                                                 as O
#                                    succinylcholine B-drug
#                                                 or O
#                                    organophosphate B-drug_n
#                                                and O
#                                          carbamate B-drug_n
#                                       insecticides I-drug_n
#                                                  . O

# %%
for tokenized_token, tokenized_tag in tokenized_tokens_tags:
    print("{:>{}} {:<{}}".format(tokenized_token ,width, tokenized_tag, width))
# Out:
#                                            phospho B-drug-effect
#                                             ##line B-drug-effect
#                                             iodide I-drug-effect
#                                            potenti O
#                                             ##ates O
#                                              other O
#                                            choline B-group-effect
#                                             ##ster B-group-effect
#                                              ##ase B-group-effect
#                                         inhibitors I-group-effect
#                                               such O
#                                                 as O
#                                             succin B-drug
#                                               ##yl B-drug
#                                          ##choline B-drug
#                                                 or O
#                                              organ B-drug_n
#                                       ##ophosphate B-drug_n
#                                                and O
#                                               carb B-drug_n
#                                            ##amate B-drug_n
#                                           insectic I-drug_n
#                                             ##ides I-drug_n
#                                                  . O
#                                              [PAD] O
#                                              [PAD] O
#                                              [PAD] O
#                                              [PAD] O
#                                              [PAD] O
#                                              [PAD] O
#                                              [PAD] O
#                                              [PAD] O
#                                              [PAD] O
#                                              [PAD] O
#                                              [PAD] O
#                                              [PAD] O
#                                              [PAD] O
#                                              [PAD] O
#                                              [PAD] O
#                                              [PAD] O
#                                              [PAD] O
#                                              [PAD] O
#                                              [PAD] O
#                                              [PAD] O
#                                              [PAD] O
#                                              [PAD] O
#                                              [PAD] O
#                                              [PAD] O
#                                              [PAD] O
#                                              [PAD] O
#                                              [PAD] O
#                                              [PAD] O
#                                              [PAD] O
#                                              [PAD] O
#                                              [PAD] O
#                                              [PAD] O
#                                              [PAD] O
#                                              [PAD] O
#                                              [PAD] O
#                                              [PAD] O
#                                              [PAD] O
#                                              [PAD] O
#                                              [PAD] O
#                                              [PAD] O
#                                              [PAD] O
#                                              [PAD] O
#                                              [PAD] O
#                                              [PAD] O
#                                              [PAD] O
#                                              [PAD] O

# %% [markdown]
# ## Knowledge Graph Visualization

# %%
ddi_data = extract_ddi_data(train_data)

# %%
knowledge_graph = pd.DataFrame(columns=['drug1', 'drug2', 'edge'])

# %%
ddi_data[0]
# Out:
# {'relations': {'entity1': {'text': 'halofantrine',
#    'type': 'drug',
#    'char_offset': [(79, 90)]},
#   'entity2': {'text': 'Mefloquine',
#    'type': 'drug',
#    'char_offset': [(147, 156)]},
#   'ddi': True,
#   'type': 'advise'},
#  'sentence': 'Because of the danger of a potentially fatal prolongation of the QTc interval, halofantrine must not be given simultaneously with or subsequent to Mefloquine.'}

# %%
knowledge_graph = pd.DataFrame(columns=['drug1', 'drug2', 'edge'])
for data in ddi_data:
    if data['relations']['ddi']:
        temp_df = pd.DataFrame({'drug1':[data['relations']['entity1']['text']], 'drug2':[data['relations']['entity2']['text']], 'edge':[data['relations']['type']]})
        knowledge_graph = pd.concat([knowledge_graph, temp_df], axis=0)
knowledge_graph = knowledge_graph.reset_index()

# %%
knowledge_graph['edge'].value_counts()
# Out:
# effect       1518
# mechanism    1167
# advise        734
# int           168
# unknown         1
# Name: edge, dtype: int64

# %%
G = nx.from_pandas_edgelist(knowledge_graph[:300], "drug1", "drug2", edge_attr=True, create_using=nx.MultiDiGraph())

# %%
plt.figure(figsize=(13, 15))

pos = nx.spring_layout(G)
nx.draw(G, with_labels=True, node_color='red', edge_cmap=plt.cm.Blues, pos=pos)
plt.show()

# %%
model.config
# Out:
# BertConfig {
#   "_name_or_path": "bert-base-uncased",
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.19.2",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 30522
# }
