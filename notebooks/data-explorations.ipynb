# %% [markdown]
# ## Entities and pair-relationships datasets

# %%
## imports

# data parsing and processing
import pandas as pd
import numpy as np
import os
import glob
import random
import re
import xml.etree.ElementTree as ET
import json

# ML learning
from sklearn.model_selection import train_test_split
from transformers import InputExample

# source paths
DATA_PATH = "../data/"

# %%
# functions and classes
def parse_pgr_xml(file_path):
    tree = ET.parse(file_path)
    root = tree.getroot()
    data = []
    
    for sentence in root.findall('sentence'):
        text = sentence.attrib['text']
        pairs = []
        
        for pair in sentence.findall('pair'):
            e1_id = pair.attrib['e1']
            e2_id = pair.attrib['e2']
            relation = pair.attrib['relation'] == 'true'
            pairs.append((e1_id, e2_id, relation))
        
        entities = {
            entity.attrib['id']: {
                'text': entity.attrib['text'],
                'type': entity.attrib['type'],
                'ontology_id': entity.attrib['ontology_id']
            }
            for entity in sentence.findall('entity')
        }
        
        for e1_id, e2_id, relation in pairs:
            data.append({
                'sentence': text,
                'entity1': entities[e1_id],
                'entity2': entities[e2_id],
                'relation': relation,
            })
    
    return data

def parse_ddi_xml(file_path):
    tree = ET.parse(file_path)
    root = tree.getroot()
    data = []

    filename = os.path.splitext(os.path.basename(file_path))[0]
    
    for sentence in root.findall('.//sentence'):
        text = sentence.attrib['text']
        text_id = sentence.attrib['id']
        pairs = []
        
        for pair in sentence.findall('.//pair'):
            e1_id = pair.attrib['e1']
            e2_id = pair.attrib['e2']
            ddi = pair.attrib['ddi'] == 'true'
            ddi_type = pair.attrib.get('type', 'unknown')
            pairs.append((e1_id, e2_id, ddi, ddi_type))
        
        entities = {}
        for entity in sentence.findall('.//entity'):
            char_offset_str = entity.attrib['charOffset']
            entity_spans = char_offset_str.split(';')
            spans = []
            for span in entity_spans:
                start, end = map(int, span.split('-'))
                spans.append((start, end))
            if spans:
                entities[entity.attrib['id']] = {
                    'text': entity.attrib['text'],
                    'type': entity.attrib['type'],
                    'char_offset': spans
                }
            else:
                entities[entity.attrib['id']] = {
                    'text': entity.attrib['text'],
                    'type': entity.attrib['type'],
                    'char_offset': None
                }
        
        for e1_id, e2_id, ddi, ddi_type in pairs:
            data.append({
                'filename': filename,
                'sentence': text,
                'sent_id': text_id,
                'entity1': {
                    'text': entities[e1_id]['text'],
                    'type': entities[e1_id]['type'],
                    'char_offset': entities[e1_id]['char_offset']
                },
                'entity2': {
                    'text': entities[e2_id]['text'],
                    'type': entities[e2_id]['type'],
                    'char_offset': entities[e2_id]['char_offset']
                },
                'ddi': ddi,
                'type': ddi_type,
                'all_ents': entities
            })
    
    return data


def save_data(data, filename):
    with open(filename, 'w') as f:
        json.dump(data, f)

def preprocess_data(*corpus_paths, parse_function):
    """
    Preprocess corpora of XML files for entity extraction with provided paths and parsing function.
    Returns a list of sentences with entity/relationship pairs
    """
    data = []
    for corpus_path in corpus_paths:
        for file in os.listdir(corpus_path):
            if file.endswith('.xml'):
                file_path = os.path.join(corpus_path, file)
                data.extend(parse_function(file_path))
    
    return data

def create_train_val_split(data, val_split=0.1):
    """
    shuffles and splits the data 
    """
    random.shuffle(data)
    val_size = int(len(data) * val_split)
    train_data = data[:-val_size]
    val_data = data[-val_size:]
    return train_data, val_data

def extract_ner_data(data):
    ner_data = []
    for instance in data:
        input_data = {}
        input_data['sentence'] = instance['sentence']
        input_data['entities'] = []
        for value in instance['all_ents'].values():
            input_data['entities'].append(value)
        ner_data.append(input_data)
    return ner_data


def generate_conll_format(sentence, entities):
    # Initialize an empty list to store token labels
    labels = ['O'] * len(sentence)

    # Assign labels using character offsets
    for entity in entities:
        span = entity['char_offset']
        for start, end in span:
            if start < len(sentence) and end <= len(sentence):
                labels[start] = f"B-{entity['type']}"
                for i in range(start + 1, end):
                    labels[i] = f"I-{entity['type']}"

    # Tokenize the sentence using regex to split on whitespace or special characters
    pattern = r"(\w+|\S)"
    tokens = [match.group() for match in re.finditer(pattern, sentence)]

    # Combine tokens and labels into the CoNLL format
    conll_format = {}
    conll_format['tokens'] = []
    conll_format['tags'] = []
    token_start = 0
    for token in tokens:
        token_start = sentence.find(token, token_start)
        token_end = token_start + len(token) - 1
        token_label = labels[token_start:token_end+1]
        
        # Find the main label by checking if there are any "B-" or "I-" labels in the token_label list
        main_label = next((label for label in token_label if label.startswith("B-") or label.startswith("I-")), 'O')
        
        #conll_format += f"{token} {main_label}\n"
        conll_format['tokens'].append(token)
        conll_format['tags'].append(main_label)
        token_start = token_end + 1

    return conll_format

class REDataset(Dataset): # Relation Extraction
    def __init__(self, data, tokenizer, max_length=128):
        self.data = data
        self.tokenizer = tokenizer
        self.max_length = max_length

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        item = self.data[idx]
        sentence = item['sentence']
        entity1 = item['entity1']
        entity2 = item['entity2']
        relation = int(item['relation'])

        # Tokenize the text, add special tokens [CLS] and [SEP]
        inputs = self.tokenizer.encode_plus(
            f"{entity1} [SEP] {entity2} [SEP] {sentence}",
            add_special_tokens=True,
            max_length=self.max_length,
            padding='max_length',
            truncation=True,
            return_tensors='pt'
        )

        input_ids = inputs['input_ids'].squeeze(0)
        attention_mask = inputs['attention_mask'].squeeze(0)
        return {
            'input_ids': input_ids,
            'attention_mask': attention_mask,
            'label': torch.tensor(relation, dtype=torch.long),
        }
def tokenize_and_preserve_labels(example, tokenizer):
    """
    Word piece tokenization makes it difficult to match word labels
    back up with individual word pieces. This function tokenizes each
    word one at a time so that it is easier to preserve the correct
    label for each subword.
    """

    tokenized_sentence = []
    labels = []

    tokens = example["tokens"]
    text_labels = example["tags"]

    if len(tokens) != len(text_labels):
        raise ValueError("Length of tokens and text_labels should be the same")

    for word, label in zip(tokens, text_labels):

        # tokenize word and count # of subword tokens
        tokenized_word = tokenizer.tokenize(word)
        n_subwords = len(tokenized_word)

        # add tokenized word to the final tokenized word list
        tokenized_sentence.extend(tokenized_word)

        # add label and multiply by subword length
        labels.extend([label] * n_subwords)

    return tokenized_sentence, labels

# %%
CORPORA_PATH = "raw/pgr-crowd/corpora/"

# Preprocess training data
train_folder = DATA_PATH + CORPORA_PATH + "amazon_train/"
train_data = preprocess_data(train_folder, parse_function=parse_pgr_xml)

# Preprocess test datapg
test_folder = DATA_PATH + CORPORA_PATH + "consensus_test/"
test_data = preprocess_data(test_folder, parse_function=parse_pgr_xml)

# Split the data into training and validation sets (80% training, 20% validation)
train_data, val_data = train_test_split(train_data, test_size=0.2, random_state=42)
len(train_data), len(val_data), len(test_data)
# Out:
# (3602, 901, 1792)

# %%
SAVE_PATH = DATA_PATH + "preprocessed/pgr-crowd/"

# save the data to files
save_data(train_data, SAVE_PATH + 'train.json')
save_data(test_data, SAVE_PATH + 'test.json')
save_data(val_data, SAVE_PATH + 'val.json')

# %%
# Hyperparameters
batch_size = 16
num_epochs = 3
learning_rate = 2e-5
max_length = 128

# Load pre-trained BERT model and tokenizer
model = BertForSequenceClassification.from_pretrained('bert-base-uncased', num_labels=2)
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

# Create Dataset and DataLoader
train_dataset = REDataset(train_data, tokenizer, max_length)
val_dataset = REDataset(val_data, tokenizer, max_length)
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_dataloader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

# Move model to GPU if available
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model.to(device)

# Set up the optimizer and learning rate scheduler
optimizer = AdamW(model.parameters(), lr=learning_rate)
total_steps = len(train_dataloader) * num_epochs
scheduler = get_linear_schedule_with_warmup(optimizer, num_warmup_steps=0, num_training_steps=total_steps)

# Training loop
model.train()
for epoch in range(num_epochs):
    for batch in train_dataloader:
        input_ids = batch['input_ids'].to(device)
        attention_mask = batch['attention_mask'].to(device)
        labels = batch['label'].to(device)

        outputs = model(input_ids, attention_mask=attention_mask, labels=labels)
        loss = outputs.loss

        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
        optimizer.step()
        scheduler.step()
        optimizer.zero_grad()

    # Evaluation loop
    model.eval()
    total_eval_loss = 0
    total_eval_accuracy = 0
    for batch in val_dataloader:
        input_ids = batch['input_ids'].to(device)
        attention_mask = batch['attention_mask'].to(device)
        labels = batch['label'].to(device)
        
        with torch.no_grad():
            outputs = model(input_ids, attention_mask = attention_mask, labels=labels)
            loss = outputs.loss
            logits = outputs.logits
            
        total_eval_loss += loss.item()
        
        preds = torch.argmax(logits, dim=1).detach.cpu().numpy()
        true_labels = labels.detach().cpu().numpy()
        total_eval_accuray += (preds == true_labels).sum()
        
    arg_val_loss = total_eval_loss / len(val_dataloader)
    arg_val_accuracy = total_eval_accuracy / len(val_dataset)
    print(f"Epoch {epoch + 1}/{num_epochs}: Val Loss = {avg_val_loss:.4f}, Val Acc = {avg_val_accuracy:.4f}")

# Save the fine-tuned model
model.save_pretrained("bert_relation_extraction")
tokenizer.save_pretrained("bert_relation_extraction")
# Out:
# {'sentence': 'Genome-wide association studies have identified loci at 15q25 (iron ion transport) and 4q22 (regulation of small GTPase mediated signal transduction), associated with lung cancer (LC) and chronic obstructive pulmonary disease (intracellular protein transport).',
#  'entity1': 'regulation of small GTPase mediated signal transduction',
#  'entity2': 'cancer',
#  'relation': True}

# %% [markdown]
# # DDI DrugBank

# %%
CORPORA_PATH = "raw/ddi-corpus/APIforDDICorpus/DDICorpus/"

# Preprocess training data
train_folder_drugbank = DATA_PATH + CORPORA_PATH + "Train/DrugBank/"
train_folder_medline = DATA_PATH + CORPORA_PATH + "Train/Medline/"
train_data = preprocess_data(train_folder_drugbank, train_folder_medline, parse_function = parse_ddi_xml)

# # Preprocess test data
test_folder_drugbank = DATA_PATH + CORPORA_PATH + "Test/Test for DrugNER task/DrugBank/"
test_folder_medline = DATA_PATH + CORPORA_PATH + "Test/Test for DrugNER task/MedLine/"

# Preprocess test data
test_data = preprocess_data(test_folder_drugbank, test_folder_medline, parse_function=parse_ddi_xml)
# # Split the data into training and validation sets (80% training, 20% validation)
train_data, val_data = create_train_val_split(train_data)
len(train_data), len(val_data), len(test_data)
# Out:
# (25013, 2779, 941)

# %%
for data in train_data[:10]:
    print(data)
# Out:
# {'filename': 'Duloxetine_ddi', 'sentence': 'Therefore, co-administration of Duloxetine with other drugs that are extensively metabolized by this isozyme and which have a narrow therapeutic index, including certain antidepressants (tricyclic antidepressants [TCAs], such as nortriptyline, amitriptyline, and imipramine), phenothiazines and Type 1C antiarrhythmics (e.g., propafenone, flecainide), should be approached with caution.', 'sent_id': 'DDI-DrugBank.d548.s9', 'entity1': {'text': 'Duloxetine', 'type': 'drug', 'char_offset': [(32, 41)]}, 'entity2': {'text': 'nortriptyline', 'type': 'drug', 'char_offset': [(229, 241)]}, 'ddi': True, 'type': 'advise', 'all_ents': {'DDI-DrugBank.d548.s9.e0': {'text': 'Duloxetine', 'type': 'drug', 'char_offset': [(32, 41)]}, 'DDI-DrugBank.d548.s9.e1': {'text': 'antidepressants', 'type': 'group', 'char_offset': [(170, 184)]}, 'DDI-DrugBank.d548.s9.e2': {'text': 'tricyclic antidepressants', 'type': 'group', 'char_offset': [(187, 211)]}, 'DDI-DrugBank.d548.s9.e3': {'text': 'TCAs', 'type': 'group', 'char_offset': [(214, 217)]}, 'DDI-DrugBank.d548.s9.e4': {'text': 'nortriptyline', 'type': 'drug', 'char_offset': [(229, 241)]}, 'DDI-DrugBank.d548.s9.e5': {'text': 'amitriptyline', 'type': 'drug', 'char_offset': [(244, 256)]}, 'DDI-DrugBank.d548.s9.e6': {'text': 'imipramine', 'type': 'drug', 'char_offset': [(263, 272)]}, 'DDI-DrugBank.d548.s9.e7': {'text': 'phenothiazines', 'type': 'group', 'char_offset': [(276, 289)]}, 'DDI-DrugBank.d548.s9.e8': {'text': 'Type 1C antiarrhythmics', 'type': 'group', 'char_offset': [(295, 317)]}, 'DDI-DrugBank.d548.s9.e9': {'text': 'propafenone', 'type': 'drug', 'char_offset': [(326, 336)]}, 'DDI-DrugBank.d548.s9.e10': {'text': 'flecainide', 'type': 'drug', 'char_offset': [(339, 348)]}}}
# {'filename': '11217867', 'sentence': 'In comparison with haloperidol, the adverse events reported significantly more frequently with olanzapine in > or = 3.5% of patients were dry mouth, bodyweight gain and increased appetite and compared with risperidone, only bodyweight gain occurred significantly more frequently with olanzapine. ', 'sent_id': 'DDI-MedLine.d83.s13', 'entity1': {'text': 'haloperidol', 'type': 'drug', 'char_offset': [(19, 29)]}, 'entity2': {'text': 'olanzapine', 'type': 'drug', 'char_offset': [(284, 293)]}, 'ddi': False, 'type': 'unknown', 'all_ents': {'DDI-MedLine.d83.s13.e0': {'text': 'haloperidol', 'type': 'drug', 'char_offset': [(19, 29)]}, 'DDI-MedLine.d83.s13.e1': {'text': 'olanzapine', 'type': 'drug', 'char_offset': [(95, 104)]}, 'DDI-MedLine.d83.s13.e2': {'text': 'risperidone', 'type': 'drug', 'char_offset': [(206, 216)]}, 'DDI-MedLine.d83.s13.e3': {'text': 'olanzapine', 'type': 'drug', 'char_offset': [(284, 293)]}}}
# {'filename': 'Etonogestrel_ddi', 'sentence': 'Etonogestrel may interact with the following medications: acetaminophen (Tylenol), antibiotics such as ampicillin and tetracycline, anticonvulsants (Dilantin, Phenobarbital, Tegretol, Trileptal, Topamax, Felbatol), antifungals (Gris-PEG, Nizoral, Sporanox), atorvastatin (Lipitor), clofibrate (Atromid-S), cyclosporine (Neoral, Sandimmune), HIV drugs classified as protease inhibitors (Agenerase, Crixivan, Fortovase, Invirase, Kaletra, Norvir, Viracept), morphine (Astramorph, Kadian, MS Contin), phenylbutazone, prednisolone (Prelone), rifadin (rifampin), St. Johns wort, temazepam, theophylline (Theo-Dur), and vitamin C.', 'sent_id': 'DDI-DrugBank.d484.s0', 'entity1': {'text': 'tetracycline', 'type': 'drug', 'char_offset': [(118, 129)]}, 'entity2': {'text': 'Trileptal', 'type': 'brand', 'char_offset': [(184, 192)]}, 'ddi': False, 'type': 'unknown', 'all_ents': {'DDI-DrugBank.d484.s0.e0': {'text': 'Etonogestrel', 'type': 'drug', 'char_offset': [(0, 11)]}, 'DDI-DrugBank.d484.s0.e1': {'text': 'acetaminophen', 'type': 'drug', 'char_offset': [(58, 70)]}, 'DDI-DrugBank.d484.s0.e2': {'text': 'Tylenol', 'type': 'brand', 'char_offset': [(73, 79)]}, 'DDI-DrugBank.d484.s0.e3': {'text': 'antibiotics', 'type': 'group', 'char_offset': [(83, 93)]}, 'DDI-DrugBank.d484.s0.e4': {'text': 'ampicillin', 'type': 'drug', 'char_offset': [(103, 112)]}, 'DDI-DrugBank.d484.s0.e5': {'text': 'tetracycline', 'type': 'drug', 'char_offset': [(118, 129)]}, 'DDI-DrugBank.d484.s0.e6': {'text': 'anticonvulsants', 'type': 'group', 'char_offset': [(132, 146)]}, 'DDI-DrugBank.d484.s0.e7': {'text': 'Dilantin', 'type': 'brand', 'char_offset': [(149, 156)]}, 'DDI-DrugBank.d484.s0.e8': {'text': 'Phenobarbital', 'type': 'drug', 'char_offset': [(159, 171)]}, 'DDI-DrugBank.d484.s0.e9': {'text': 'Tegretol', 'type': 'brand', 'char_offset': [(174, 181)]}, 'DDI-DrugBank.d484.s0.e10': {'text': 'Trileptal', 'type': 'brand', 'char_offset': [(184, 192)]}, 'DDI-DrugBank.d484.s0.e11': {'text': 'Topamax', 'type': 'brand', 'char_offset': [(195, 201)]}, 'DDI-DrugBank.d484.s0.e12': {'text': 'Felbatol', 'type': 'brand', 'char_offset': [(204, 211)]}, 'DDI-DrugBank.d484.s0.e13': {'text': 'antifungals', 'type': 'group', 'char_offset': [(215, 225)]}, 'DDI-DrugBank.d484.s0.e14': {'text': 'Gris-PEG', 'type': 'brand', 'char_offset': [(228, 235)]}, 'DDI-DrugBank.d484.s0.e15': {'text': 'Nizoral', 'type': 'brand', 'char_offset': [(238, 244)]}, 'DDI-DrugBank.d484.s0.e16': {'text': 'Sporanox', 'type': 'brand', 'char_offset': [(247, 254)]}, 'DDI-DrugBank.d484.s0.e17': {'text': 'atorvastatin', 'type': 'drug', 'char_offset': [(258, 269)]}, 'DDI-DrugBank.d484.s0.e18': {'text': 'Lipitor', 'type': 'brand', 'char_offset': [(272, 278)]}, 'DDI-DrugBank.d484.s0.e19': {'text': 'clofibrate', 'type': 'drug', 'char_offset': [(282, 291)]}, 'DDI-DrugBank.d484.s0.e20': {'text': 'Atromid-S', 'type': 'brand', 'char_offset': [(294, 302)]}, 'DDI-DrugBank.d484.s0.e21': {'text': 'cyclosporine', 'type': 'drug', 'char_offset': [(306, 317)]}, 'DDI-DrugBank.d484.s0.e22': {'text': 'Neoral', 'type': 'brand', 'char_offset': [(320, 325)]}, 'DDI-DrugBank.d484.s0.e23': {'text': 'Sandimmune', 'type': 'brand', 'char_offset': [(328, 337)]}, 'DDI-DrugBank.d484.s0.e24': {'text': 'protease inhibitors', 'type': 'group', 'char_offset': [(365, 383)]}, 'DDI-DrugBank.d484.s0.e25': {'text': 'Agenerase', 'type': 'brand', 'char_offset': [(386, 394)]}, 'DDI-DrugBank.d484.s0.e26': {'text': 'Crixivan', 'type': 'brand', 'char_offset': [(397, 404)]}, 'DDI-DrugBank.d484.s0.e27': {'text': 'Fortovase', 'type': 'brand', 'char_offset': [(407, 415)]}, 'DDI-DrugBank.d484.s0.e28': {'text': 'Invirase', 'type': 'brand', 'char_offset': [(418, 425)]}, 'DDI-DrugBank.d484.s0.e29': {'text': 'Kaletra', 'type': 'brand', 'char_offset': [(428, 434)]}, 'DDI-DrugBank.d484.s0.e30': {'text': 'Norvir', 'type': 'brand', 'char_offset': [(437, 442)]}, 'DDI-DrugBank.d484.s0.e31': {'text': 'Viracept', 'type': 'brand', 'char_offset': [(4 ...
# {'filename': 'Glimepiride_ddi', 'sentence': '- a beta-blocker such as propranolol (Inderal), atenolol (Tenormin), acebutolol (Sectral), metoprolol (Lopressor), and others;', 'sent_id': 'DDI-DrugBank.d521.s5', 'entity1': {'text': 'beta-blocker', 'type': 'group', 'char_offset': [(4, 15)]}, 'entity2': {'text': 'acebutolol', 'type': 'drug', 'char_offset': [(69, 78)]}, 'ddi': False, 'type': 'unknown', 'all_ents': {'DDI-DrugBank.d521.s5.e0': {'text': 'beta-blocker', 'type': 'group', 'char_offset': [(4, 15)]}, 'DDI-DrugBank.d521.s5.e1': {'text': 'propranolol', 'type': 'drug', 'char_offset': [(25, 35)]}, 'DDI-DrugBank.d521.s5.e2': {'text': 'Inderal', 'type': 'brand', 'char_offset': [(38, 44)]}, 'DDI-DrugBank.d521.s5.e3': {'text': 'atenolol', 'type': 'drug', 'char_offset': [(48, 55)]}, 'DDI-DrugBank.d521.s5.e4': {'text': 'Tenormin', 'type': 'brand', 'char_offset': [(58, 65)]}, 'DDI-DrugBank.d521.s5.e5': {'text': 'acebutolol', 'type': 'drug', 'char_offset': [(69, 78)]}, 'DDI-DrugBank.d521.s5.e6': {'text': 'Sectral', 'type': 'brand', 'char_offset': [(81, 87)]}, 'DDI-DrugBank.d521.s5.e7': {'text': 'metoprolol', 'type': 'drug', 'char_offset': [(91, 100)]}, 'DDI-DrugBank.d521.s5.e8': {'text': 'Lopressor', 'type': 'brand', 'char_offset': [(103, 111)]}}}
# {'filename': 'Aripiprazole_ddi', 'sentence': 'Carbamazepine: Coadministration of carbamazepine (200 mg BID), a potent CYP3A4 inducer, with aripiprazole (30 mg QD) resulted in an approximate 70% decrease in Cmax and AUC values of both aripiprazole and its active metabolite, dehydro-aripiprazole.', 'sent_id': 'DDI-DrugBank.d509.s19', 'entity1': {'text': 'aripiprazole', 'type': 'drug', 'char_offset': [(188, 199)]}, 'entity2': {'text': 'dehydro-aripiprazole', 'type': 'drug_n', 'char_offset': [(228, 247)]}, 'ddi': False, 'type': 'unknown', 'all_ents': {'DDI-DrugBank.d509.s19.e0': {'text': 'Carbamazepine', 'type': 'drug', 'char_offset': [(0, 12)]}, 'DDI-DrugBank.d509.s19.e1': {'text': 'carbamazepine', 'type': 'drug', 'char_offset': [(35, 47)]}, 'DDI-DrugBank.d509.s19.e2': {'text': 'aripiprazole', 'type': 'drug', 'char_offset': [(93, 104)]}, 'DDI-DrugBank.d509.s19.e3': {'text': 'aripiprazole', 'type': 'drug', 'char_offset': [(188, 199)]}, 'DDI-DrugBank.d509.s19.e4': {'text': 'dehydro-aripiprazole', 'type': 'drug_n', 'char_offset': [(228, 247)]}}}
# {'filename': 'Alteplase_ddi', 'sentence': 'Use of Antithrombotics Aspirin and heparin have been administered concomitantly with and following infusions of Activase in the management of acute myocardial infarction or pulmonary embolism.', 'sent_id': 'DDI-DrugBank.d508.s2', 'entity1': {'text': 'Antithrombotics', 'type': 'group', 'char_offset': [(7, 21)]}, 'entity2': {'text': 'Activase', 'type': 'brand', 'char_offset': [(112, 119)]}, 'ddi': False, 'type': 'unknown', 'all_ents': {'DDI-DrugBank.d508.s2.e0': {'text': 'Antithrombotics', 'type': 'group', 'char_offset': [(7, 21)]}, 'DDI-DrugBank.d508.s2.e1': {'text': 'Aspirin', 'type': 'brand', 'char_offset': [(23, 29)]}, 'DDI-DrugBank.d508.s2.e2': {'text': 'heparin', 'type': 'drug', 'char_offset': [(35, 41)]}, 'DDI-DrugBank.d508.s2.e3': {'text': 'Activase', 'type': 'brand', 'char_offset': [(112, 119)]}}}
# {'filename': 'Butalbital_ddi', 'sentence': 'Butalbital, acetaminophen and caffeine may enhance the effects of: other narcotic analgesics, alcohol, general anesthetics, tranquilizers such as chlordiazepoxide, sedative-hypnotics, or other CNS depressants, causing increased CNS depression.', 'sent_id': 'DDI-DrugBank.d559.s1', 'entity1': {'text': 'acetaminophen', 'type': 'drug', 'char_offset': [(12, 24)]}, 'entity2': {'text': 'anesthetics', 'type': 'group', 'char_offset': [(111, 121)]}, 'ddi': True, 'type': 'effect', 'all_ents': {'DDI-DrugBank.d559.s1.e0': {'text': 'Butalbital', 'type': 'drug', 'char_offset': [(0, 9)]}, 'DDI-DrugBank.d559.s1.e1': {'text': 'acetaminophen', 'type': 'drug', 'char_offset': [(12, 24)]}, 'DDI-DrugBank.d559.s1.e2': {'text': 'caffeine', 'type': 'drug', 'char_offset': [(30, 37)]}, 'DDI-DrugBank.d559.s1.e3': {'text': 'narcotic analgesic', 'type': 'group', 'char_offset': [(73, 90)]}, 'DDI-DrugBank.d559.s1.e4': {'text': 'alcohol', 'type': 'drug', 'char_offset': [(94, 100)]}, 'DDI-DrugBank.d559.s1.e5': {'text': 'anesthetics', 'type': 'group', 'char_offset': [(111, 121)]}, 'DDI-DrugBank.d559.s1.e6': {'text': 'tranquilizers', 'type': 'group', 'char_offset': [(124, 136)]}, 'DDI-DrugBank.d559.s1.e7': {'text': 'chlordiazepoxide', 'type': 'drug', 'char_offset': [(146, 161)]}, 'DDI-DrugBank.d559.s1.e8': {'text': 'sedative-hypnotics', 'type': 'group', 'char_offset': [(164, 181)]}, 'DDI-DrugBank.d559.s1.e9': {'text': 'CNS depressants', 'type': 'group', 'char_offset': [(193, 207)]}}}
# {'filename': 'Sulfapyridine_ddi', 'sentence': '- Phenothiazines (acetophenazine [e.g., Tindal], chlorpromazine [e.g., Thorazine], fluphenazine [e.g., Prolixin], mesoridazine [e.g., Serentil], perphenazine [e.g., Trilafon], prochlorperazine [e.g., Compazine], promazine [e.g., Sparine], promethazine [e.g., Phenergan], thioridazine [e.g., Mellaril], trifluoperazine [e.g., Stelazine], triflupromazine [e.g., Vesprin], trimeprazine [e.g., Temaril]) or', 'sent_id': 'DDI-DrugBank.d179.s21', 'entity1': {'text': 'Phenergan', 'type': 'brand', 'char_offset': [(259, 267)]}, 'entity2': {'text': 'triflupromazine', 'type': 'drug', 'char_offset': [(337, 351)]}, 'ddi': False, 'type': 'unknown', 'all_ents': {'DDI-DrugBank.d179.s21.e0': {'text': 'Phenothiazines', 'type': 'group', 'char_offset': [(2, 15)]}, 'DDI-DrugBank.d179.s21.e1': {'text': 'acetophenazine', 'type': 'drug', 'char_offset': [(18, 31)]}, 'DDI-DrugBank.d179.s21.e2': {'text': 'Tindal', 'type': 'brand', 'char_offset': [(40, 45)]}, 'DDI-DrugBank.d179.s21.e3': {'text': 'chlorpromazine', 'type': 'drug', 'char_offset': [(49, 62)]}, 'DDI-DrugBank.d179.s21.e4': {'text': 'Thorazine', 'type': 'brand', 'char_offset': [(71, 79)]}, 'DDI-DrugBank.d179.s21.e5': {'text': 'fluphenazine', 'type': 'drug', 'char_offset': [(83, 94)]}, 'DDI-DrugBank.d179.s21.e6': {'text': 'Prolixin', 'type': 'brand', 'char_offset': [(103, 110)]}, 'DDI-DrugBank.d179.s21.e7': {'text': 'mesoridazine', 'type': 'brand', 'char_offset': [(114, 125)]}, 'DDI-DrugBank.d179.s21.e8': {'text': 'Serentil', 'type': 'brand', 'char_offset': [(134, 141)]}, 'DDI-DrugBank.d179.s21.e9': {'text': 'perphenazine', 'type': 'drug', 'char_offset': [(145, 156)]}, 'DDI-DrugBank.d179.s21.e10': {'text': 'Trilafon', 'type': 'brand', 'char_offset': [(165, 172)]}, 'DDI-DrugBank.d179.s21.e11': {'text': 'prochlorperazine', 'type': 'drug', 'char_offset': [(176, 191)]}, 'DDI-DrugBank.d179.s21.e12': {'text': 'Compazine', 'type': 'brand', 'char_offset': [(200, 208)]}, 'DDI-DrugBank.d179.s21.e13': {'text': 'promazine', 'type': 'drug', 'char_offset': [(212, 220)]}, 'DDI-DrugBank.d179.s21.e14': {'text': 'Sparine', 'type': 'brand', 'char_offset': [(229, 235)]}, 'DDI-DrugBank.d179.s21.e15': {'text': 'promethazine', 'type': 'drug', 'char_offset': [(239, 250)]}, 'DDI-DrugBank.d179.s21.e16': {'text': 'Phenergan', 'type': 'brand', 'char_offset': [(259, 267)]}, 'DDI-DrugBank.d179.s21.e17': {'text': 'thioridazine', 'type': 'drug', 'char_offset': [(271, 282)]}, 'DDI-DrugBank.d179.s21.e18': {'text': 'Mellaril', 'type': 'brand', 'char_offset': [(291, 298)]}, 'DDI-DrugBank.d179.s21.e19': {'text': 'trifluoperazine', 'type': 'drug', 'char_offset': [(302, 316)]}, 'DDI-DrugBank.d179.s21.e20': {'text': 'Stelazine', 'type': 'brand', 'char_offset': [(325, 333)]}, 'DDI-DrugBank.d179.s21.e21': {'text': 'triflupromazine', 'type': 'drug', 'char_offset': [(337, 351)]}, 'DDI-DrugBank.d179.s21.e22': {'text': 'Vesprin', 'type': 'brand', 'char_offset': [(360, 366)]}, 'DDI-DrugBank.d179.s21.e23': {'text': 'trimeprazine', 'type': 'drug', 'char_offset': [(370, 381)]}, 'DDI-DrugBank.d179.s21.e24': {'text': 'Temaril', 'type': 'brand', 'char_offset': [(390, 396)]}}}
# {'filename': 'Carbamazepine_ddi', 'sentence': 'Agents that have been found, or are expected to have decreased plasma levels in the presence of EQUETROTM due to induction of CYP enzymes are the following: Acetaminophen, alprazolam, amitriptyline, bupropion, buspirone, citalopram, clobazam, clonazepam, clozapine, cyclosporin, delavirdine, desipramine, diazepam, dicumarol, doxycycline, ethosuximide, felbamate, felodipine, glucocorticoids, haloperidol, itraconazole, lamotrigine, levothyroxine, lorazepam, methadone, midazolam, mirtazapine, nortriptyline, olanzapine, oral contraceptives(3), oxcarbazepine, Phenytoin(4), praziquantel, protease inhibitors, quetiapine, risperidone, theophylline, topiramate, tiagabine, tramadol, triazolam, valproate, warfarin(5) , ziprasidone, and zonisamide.', 'sent_id': 'DDI-DrugBank.d94.s11', 'entity1': {'text': 'valproate', 'type': 'drug', 'char_offset': [(692, 700)]}, 'entity2': {'text': 'warfarin', 'type': 'drug', 'char_offset': [(703, 710)]}, 'ddi': False, 'type': 'unknown', 'all_ents': {'DDI-DrugBank.d94.s11.e0': {'text': 'EQUETROTM', 'type': 'brand', 'char_offset': [(96, 104)]}, 'DDI-DrugBank.d94.s11.e1': {'text': 'Acetaminophen', 'type': 'drug', 'char_offset': [(157, 169)]}, 'DDI-DrugBank.d94.s11.e2': {'text': 'alprazolam', 'type': 'drug', 'char_offset': [(172, 181)]}, 'DDI-DrugBank.d94.s11.e3': {'text': 'amitriptyline', 'type': 'drug', 'char_offset': [(184, 196)]}, 'DDI-DrugBank.d94.s11.e4': {'text': 'bupropion', 'type': 'drug', 'char_offset': [(199, 207)]}, 'DDI-DrugBank.d94.s11.e5': {'text': 'buspirone', 'type': 'drug', 'char_offset': [(210, 218)]}, 'DDI-DrugBank.d94.s11.e6': {'text': 'citalopram', 'type': 'drug', 'char_offset': [(221, 230)]}, 'DDI-DrugBank.d94.s11.e7': {'text': 'clobazam', 'type': 'drug', 'char_offset': [(233, 240)]}, 'DDI-DrugBank.d94.s11.e8': {'text': 'clonazepam', 'type': 'drug', 'char_offset': [(243, 252)]}, 'DDI-DrugBank.d94.s11.e9': {'text': 'clozapine', 'type': 'drug', 'char_offset': [(255, 263)]}, 'DDI-DrugBank.d94.s11.e10': {'text': 'cyclosporin', 'type': 'drug', 'char_offset': [(266, 276)]}, 'DDI-DrugBank.d94.s11.e11': {'text': 'delavirdine', 'type': 'drug', 'char_offset': [(279, 289)]}, 'DDI-DrugBank.d94.s11.e12': {'text': 'desipramine', 'type': 'drug', 'char_offset': [(292, 302)]}, 'DDI-DrugBank.d94.s11.e13': {'text': 'diazepam', 'type': 'drug', 'char_offset': [(305, 312)]}, 'DDI-DrugBank.d94.s11.e14': {'text': 'dicumarol', 'type': 'drug', 'char_offset': [(315, 323)]}, 'DDI-DrugBank.d94.s11.e15': {'text': 'doxycycline', 'type': 'drug', 'char_offset': [(326, 336)]}, 'DDI-DrugBank.d94.s11.e16': {'text': 'ethosuximide', 'type': 'drug', 'char_offset': [(339, 350)]}, 'DDI-DrugBank.d94.s11.e17': {'text': 'felbamate', 'type': 'drug', 'char_offset': [(353, 361)]}, 'DDI-DrugBank.d94.s11.e18': {'text': 'felodipine', 'type': 'drug', 'char_offset': [(364, 373)]}, 'DDI-DrugBank.d94.s11.e19': {'text': 'glucocorticoids', 'type': 'group', 'char_offset': [(376, 390)]}, 'DDI-DrugBank.d94.s11.e20': {'text': 'haloperidol', 'type': 'drug', 'char_offset': [(393, 403)]}, 'DDI-DrugBank.d94.s11.e21': {'text': 'itraconazole', 'type': 'drug', 'char_offset': [(406, 417)]}, 'DDI-DrugBank.d94.s11.e22': {'text': 'lamotrigine', 'type': 'drug', 'char_offset': [(420, 430)]}, 'DDI-DrugBank.d94.s11.e23': {'text': 'levothyroxine', 'type': 'drug', 'char_offset': [(433, 445)]}, 'DDI-DrugBank.d94.s11.e24': {'text': 'lorazepam', 'type': 'drug', 'char_offset': [(448, 456)]}, 'DDI-DrugBank.d94.s11.e25': {'text': 'methadone', 'type': 'drug', 'char_offset': [(459, 467)]}, 'DDI-DrugBank.d94.s11.e26': {'text': 'midazolam', 'type': 'drug', 'char_offset': [(470, 478)]}, 'DDI-DrugBank.d94.s11.e27': {'text': 'mirtazapine', 'type': 'drug', 'char_offset': [(481, 491)]}, 'DDI-DrugBank.d94.s11.e28': {'text': 'nortriptyline', 'type': 'drug', 'char_offset': [(494, 506)]}, 'DDI-DrugBank.d94.s11.e29': {'text': 'olanzapine', 'type': 'drug', 'char_offset': [(509, 518)]}, 'DDI-DrugBank.d94.s11.e30': {'text': 'contraceptive ...
# {'filename': 'Anisindione_ddi', 'sentence': 'Drugs that have been reported to diminish oral anticoagulant response, ie, decreased prothrom-bin time response, in man significantly include: adrenocortical steroids;alcohol*;antacids;antihistamines;barbiturates;carbamazepine;chloral hydrate*;chlordiazepoxide;cholestyramine;diet high in vitamin K;diuretics*;ethchlorvynol;glutethimide;griseofulvin;haloperidol;meprobamate;oral contraceptives;paraldehyde;primidone;ranitidine*;rifampin;unreliable prothrombin time determinations;vitamin C;warfarin sodium under-dosage.', 'sent_id': 'DDI-DrugBank.d64.s29', 'entity1': {'text': 'anticoagulant', 'type': 'group', 'char_offset': [(47, 59)]}, 'entity2': {'text': 'chlordiazepoxide', 'type': 'drug', 'char_offset': [(244, 259)]}, 'ddi': True, 'type': 'effect', 'all_ents': {'DDI-DrugBank.d64.s29.e0': {'text': 'anticoagulant', 'type': 'group', 'char_offset': [(47, 59)]}, 'DDI-DrugBank.d64.s29.e1': {'text': 'adrenocortical steroids', 'type': 'group', 'char_offset': [(143, 165)]}, 'DDI-DrugBank.d64.s29.e2': {'text': 'alcohol', 'type': 'drug', 'char_offset': [(167, 173)]}, 'DDI-DrugBank.d64.s29.e3': {'text': 'antacids', 'type': 'group', 'char_offset': [(176, 183)]}, 'DDI-DrugBank.d64.s29.e4': {'text': 'antihistamines', 'type': 'group', 'char_offset': [(185, 198)]}, 'DDI-DrugBank.d64.s29.e5': {'text': 'barbiturates', 'type': 'group', 'char_offset': [(200, 211)]}, 'DDI-DrugBank.d64.s29.e6': {'text': 'carbamazepine', 'type': 'drug', 'char_offset': [(213, 225)]}, 'DDI-DrugBank.d64.s29.e7': {'text': 'chloral hydrate', 'type': 'drug', 'char_offset': [(227, 241)]}, 'DDI-DrugBank.d64.s29.e8': {'text': 'chlordiazepoxide', 'type': 'drug', 'char_offset': [(244, 259)]}, 'DDI-DrugBank.d64.s29.e9': {'text': 'cholestyramine', 'type': 'drug', 'char_offset': [(261, 274)]}, 'DDI-DrugBank.d64.s29.e10': {'text': 'vitamin K', 'type': 'group', 'char_offset': [(289, 297)]}, 'DDI-DrugBank.d64.s29.e11': {'text': 'diuretics', 'type': 'group', 'char_offset': [(299, 307)]}, 'DDI-DrugBank.d64.s29.e12': {'text': 'ethchlorvynol', 'type': 'drug', 'char_offset': [(310, 322)]}, 'DDI-DrugBank.d64.s29.e13': {'text': 'glutethimide', 'type': 'drug', 'char_offset': [(324, 335)]}, 'DDI-DrugBank.d64.s29.e14': {'text': 'griseofulvin', 'type': 'drug', 'char_offset': [(337, 348)]}, 'DDI-DrugBank.d64.s29.e15': {'text': 'haloperidol', 'type': 'drug', 'char_offset': [(350, 360)]}, 'DDI-DrugBank.d64.s29.e16': {'text': 'meprobamate', 'type': 'drug', 'char_offset': [(362, 372)]}, 'DDI-DrugBank.d64.s29.e17': {'text': 'contraceptives', 'type': 'group', 'char_offset': [(379, 392)]}, 'DDI-DrugBank.d64.s29.e18': {'text': 'paraldehyde', 'type': 'drug', 'char_offset': [(394, 404)]}, 'DDI-DrugBank.d64.s29.e19': {'text': 'primidone', 'type': 'drug', 'char_offset': [(406, 414)]}, 'DDI-DrugBank.d64.s29.e20': {'text': 'ranitidine', 'type': 'drug', 'char_offset': [(416, 425)]}, 'DDI-DrugBank.d64.s29.e21': {'text': 'rifampin', 'type': 'drug', 'char_offset': [(428, 435)]}, 'DDI-DrugBank.d64.s29.e22': {'text': 'vitamin C', 'type': 'drug', 'char_offset': [(480, 488)]}, 'DDI-DrugBank.d64.s29.e23': {'text': 'warfarin sodium', 'type': 'drug', 'char_offset': [(490, 504)]}}}

# %%
conll_sents_train = []
ner_data = extract_ner_data(train_data)
for data in ner_data:
    conll_sents_train.append(generate_conll_format(data['sentence'], data['entities']))
    
conll_sents_dev = []
ner_data = extract_ner_data(val_data)
for data in ner_data:
    conll_sents_dev.append(generate_conll_format(data['sentence'], data['entities']))
    
conll_sents_test = []
ner_data = extract_ner_data(test_data)
for data in ner_data:
    conll_sents_test.append(generate_conll_format(data['sentence'], data['entities']))

# %%
len(conll_sents_train), len(conll_sents_dev), len(conll_sents_test)
# Out:
# (25013, 2779, 941)

# %%
SAVE_PATH = DATA_PATH + "preprocessed/ddi-corpus/drug_ner/"
# save the data to files
save_data(conll_sents_train, SAVE_PATH + 'train.json')
save_data(conll_sents_test, SAVE_PATH + 'test.json')
save_data(conll_sents_dev, SAVE_PATH + 'dev.json')

# %%
conll_sents_train[0]
# Out:
# {'tokens': ['Therefore',
#   ',',
#   'co',
#   '-',
#   'administration',
#   'of',
#   'Duloxetine',
#   'with',
#   'other',
#   'drugs',
#   'that',
#   'are',
#   'extensively',
#   'metabolized',
#   'by',
#   'this',
#   'isozyme',
#   'and',
#   'which',
#   'have',
#   'a',
#   'narrow',
#   'therapeutic',
#   'index',
#   ',',
#   'including',
#   'certain',
#   'antidepressants',
#   '(',
#   'tricyclic',
#   'antidepressants',
#   '[',
#   'TCAs',
#   ']',
#   ',',
#   'such',
#   'as',
#   'nortriptyline',
#   ',',
#   'amitriptyline',
#   ',',
#   'and',
#   'imipramine',
#   ')',
#   ',',
#   'phenothiazines',
#   'and',
#   'Type',
#   '1C',
#   'antiarrhythmics',
#   '(',
#   'e',
#   '.',
#   'g',
#   '.',
#   ',',
#   'propafenone',
#   ',',
#   'flecainide',
#   ')',
#   ',',
#   'should',
#   'be',
#   'approached',
#   'with',
#   'caution',
#   '.'],
#  'tags': ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-drug',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-group',
#   'O',
#   'B-group',
#   'I-group',
#   'O',
#   'B-group',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-drug',
#   'O',
#   'B-drug',
#   'O',
#   'O',
#   'B-drug',
#   'O',
#   'O',
#   'B-group',
#   'O',
#   'B-group',
#   'I-group',
#   'I-group',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-drug',
#   'O',
#   'B-drug',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O']}

# %%
from transformers import AutoTokenizer, AutoModelForTokenClassification
import torch

#model_checkpoint = "path/to/your/fine-tuned/scibert/model"
tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")
model = AutoModelForTokenClassification.from_pretrained('bert-base-uncased')

# text = "Your text from the DDI corpus"
# inputs = tokenizer(text, return_tensors="pt", truncation=True, padding=True)
# outputs = model(**inputs)
# predictions = torch.argmax(outputs.logits, dim=-1)

# # Convert token ids back to tokens and labels
# tokens = tokenizer.convert_ids_to_tokens(inputs["input_ids"].squeeze())
# label_ids = predictions.squeeze().tolist()
# labels = [model.config.id2label[label_id] for label_id in label_ids]

# # Post-process to obtain the final entity predictions
# for token, label in zip(tokens, labels):
#     if label != "O":
#         print(f"{token} - {label}")
# Out:
# loading configuration file https://huggingface.co/bert-base-uncased/resolve/main/config.json from cache at /Users/tylerpoore/.cache/huggingface/transformers/3c61d016573b14f7f008c02c4e51a366c67ab274726fe2910691e2a761acf43e.37395cee442ab11005bcd270f3c34464dc1704b715b5d7d52b1a461abe3b9e4e
# Model config BertConfig {
#   "_name_or_path": "bert-base-uncased",
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.19.2",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 30522
# }
#
# loading file https://huggingface.co/bert-base-uncased/resolve/main/vocab.txt from cache at /Users/tylerpoore/.cache/huggingface/transformers/45c3f7a79a80e1cf0a489e5c62b43f173c15db47864303a55d623bb3c96f72a5.d789d64ebfe299b0e416afc4a169632f903f693095b4629a7ea271d5a0cf2c99
# loading file https://huggingface.co/bert-base-uncased/resolve/main/tokenizer.json from cache at /Users/tylerpoore/.cache/huggingface/transformers/534479488c54aeaf9c3406f647aa2ec13648c06771ffe269edabebd4c412da1d.7f2721073f19841be16f41b0a70b600ca6b880c8f3df6f3535cbc704371bdfa4
# loading file https://huggingface.co/bert-base-uncased/resolve/main/added_tokens.json from cache at None
# loading file https://huggingface.co/bert-base-uncased/resolve/main/special_tokens_map.json from cache at None
# loading file https://huggingface.co/bert-base-uncased/resolve/main/tokenizer_config.json from cache at /Users/tylerpoore/.cache/huggingface/transformers/c1d7f0a763fb63861cc08553866f1fc3e5a6f4f07621be277452d26d71303b7e.20430bd8e10ef77a7d2977accefe796051e01bc2fc4aa146bc862997a1a15e79
# loading configuration file https://huggingface.co/bert-base-uncased/resolve/main/config.json from cache at /Users/tylerpoore/.cache/huggingface/transformers/3c61d016573b14f7f008c02c4e51a366c67ab274726fe2910691e2a761acf43e.37395cee442ab11005bcd270f3c34464dc1704b715b5d7d52b1a461abe3b9e4e
# Model config BertConfig {
#   "_name_or_path": "bert-base-uncased",
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.19.2",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 30522
# }
#
# loading configuration file https://huggingface.co/bert-base-uncased/resolve/main/config.json from cache at /Users/tylerpoore/.cache/huggingface/transformers/3c61d016573b14f7f008c02c4e51a366c67ab274726fe2910691e2a761acf43e.37395cee442ab11005bcd270f3c34464dc1704b715b5d7d52b1a461abe3b9e4e
# Model config BertConfig {
#   "_name_or_path": "bert-base-uncased",
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.19.2",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 30522
# }
#
# loading weights file https://huggingface.co/bert-base-uncased/resolve/main/pytorch_model.bin from cache at /Users/tylerpoore/.cache/huggingface/transformers/a8041bf617d7f94ea26d15e218abd04afc2004805632abc0ed2066aa16d50d04.faf6ea826ae9c5867d12b22257f9877e6b8367890837bd60f7c54a29633f7f2f
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForTokenClassification: ['cls.seq_relationship.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForTokenClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
train_data[0]
# Out:
# {'filename': 'Duloxetine_ddi',
#  'sentence': 'Therefore, co-administration of Duloxetine with other drugs that are extensively metabolized by this isozyme and which have a narrow therapeutic index, including certain antidepressants (tricyclic antidepressants [TCAs], such as nortriptyline, amitriptyline, and imipramine), phenothiazines and Type 1C antiarrhythmics (e.g., propafenone, flecainide), should be approached with caution.',
#  'sent_id': 'DDI-DrugBank.d548.s9',
#  'entity1': {'text': 'Duloxetine', 'type': 'drug', 'char_offset': [(32, 41)]},
#  'entity2': {'text': 'nortriptyline',
#   'type': 'drug',
#   'char_offset': [(229, 241)]},
#  'ddi': True,
#  'type': 'advise',
#  'all_ents': {'DDI-DrugBank.d548.s9.e0': {'text': 'Duloxetine',
#    'type': 'drug',
#    'char_offset': [(32, 41)]},
#   'DDI-DrugBank.d548.s9.e1': {'text': 'antidepressants',
#    'type': 'group',
#    'char_offset': [(170, 184)]},
#   'DDI-DrugBank.d548.s9.e2': {'text': 'tricyclic antidepressants',
#    'type': 'group',
#    'char_offset': [(187, 211)]},
#   'DDI-DrugBank.d548.s9.e3': {'text': 'TCAs',
#    'type': 'group',
#    'char_offset': [(214, 217)]},
#   'DDI-DrugBank.d548.s9.e4': {'text': 'nortriptyline',
#    'type': 'drug',
#    'char_offset': [(229, 241)]},
#   'DDI-DrugBank.d548.s9.e5': {'text': 'amitriptyline',
#    'type': 'drug',
#    'char_offset': [(244, 256)]},
#   'DDI-DrugBank.d548.s9.e6': {'text': 'imipramine',
#    'type': 'drug',
#    'char_offset': [(263, 272)]},
#   'DDI-DrugBank.d548.s9.e7': {'text': 'phenothiazines',
#    'type': 'group',
#    'char_offset': [(276, 289)]},
#   'DDI-DrugBank.d548.s9.e8': {'text': 'Type 1C antiarrhythmics',
#    'type': 'group',
#    'char_offset': [(295, 317)]},
#   'DDI-DrugBank.d548.s9.e9': {'text': 'propafenone',
#    'type': 'drug',
#    'char_offset': [(326, 336)]},
#   'DDI-DrugBank.d548.s9.e10': {'text': 'flecainide',
#    'type': 'drug',
#    'char_offset': [(339, 348)]}}}

# %%
data = conll_sents_train[0]
# Out:
# {'tokens': ['Therefore',
#   ',',
#   'co',
#   '-',
#   'administration',
#   'of',
#   'Duloxetine',
#   'with',
#   'other',
#   'drugs',
#   'that',
#   'are',
#   'extensively',
#   'metabolized',
#   'by',
#   'this',
#   'isozyme',
#   'and',
#   'which',
#   'have',
#   'a',
#   'narrow',
#   'therapeutic',
#   'index',
#   ',',
#   'including',
#   'certain',
#   'antidepressants',
#   '(',
#   'tricyclic',
#   'antidepressants',
#   '[',
#   'TCAs',
#   ']',
#   ',',
#   'such',
#   'as',
#   'nortriptyline',
#   ',',
#   'amitriptyline',
#   ',',
#   'and',
#   'imipramine',
#   ')',
#   ',',
#   'phenothiazines',
#   'and',
#   'Type',
#   '1C',
#   'antiarrhythmics',
#   '(',
#   'e',
#   '.',
#   'g',
#   '.',
#   ',',
#   'propafenone',
#   ',',
#   'flecainide',
#   ')',
#   ',',
#   'should',
#   'be',
#   'approached',
#   'with',
#   'caution',
#   '.'],
#  'tags': ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-drug',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-group',
#   'O',
#   'B-group',
#   'I-group',
#   'O',
#   'B-group',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-drug',
#   'O',
#   'B-drug',
#   'O',
#   'O',
#   'B-drug',
#   'O',
#   'O',
#   'B-group',
#   'O',
#   'B-group',
#   'I-group',
#   'I-group',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-drug',
#   'O',
#   'B-drug',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O']}

# %%
tokens, tags = tokenize_and_preserve_labels(conll_sents_train[0], tokenizer)
for i in range(len(tokens)):
    print(tokens[i], tags[i])
# Out:
# therefore O
# , O
# co O
# - O
# administration O
# of O
# du B-drug
# ##lo B-drug
# ##x B-drug
# ##eti B-drug
# ##ne B-drug
# with O
# other O
# drugs O
# that O
# are O
# extensively O
# meta O
# ##bol O
# ##ized O
# by O
# this O
# iso O
# ##zy O
# ##me O
# and O
# which O
# have O
# a O
# narrow O
# therapeutic O
# index O
# , O
# including O
# certain O
# anti B-group
# ##de B-group
# ##press B-group
# ##ants B-group
# ( O
# tri B-group
# ##cy B-group
# ##cl B-group
# ##ic B-group
# anti I-group
# ##de I-group
# ##press I-group
# ##ants I-group
# [ O
# tc B-group
# ##as B-group
# ] O
# , O
# such O
# as O
# nor B-drug
# ##trip B-drug
# ##ty B-drug
# ##line B-drug
# , O
# ami B-drug
# ##trip B-drug
# ##ty B-drug
# ##line B-drug
# , O
# and O
# im B-drug
# ##ip B-drug
# ##ram B-drug
# ##ine B-drug
# ) O
# , O
# ph B-group
# ##eno B-group
# ##thi B-group
# ##azi B-group
# ##nes B-group
# and O
# type B-group
# 1 I-group
# ##c I-group
# anti I-group
# ##ar I-group
# ##rh I-group
# ##yt I-group
# ##hmi I-group
# ##cs I-group
# ( O
# e O
# . O
# g O
# . O
# , O
# prop B-drug
# ##af B-drug
# ##eno B-drug
# ##ne B-drug
# , O
# fl B-drug
# ##eca B-drug
# ##ini B-drug
# ##de B-drug
# ) O
# , O
# should O
# be O
# approached O
# with O
# caution O
# . O

# %%
import re

regex_pattern = r"(\w+|\W)"

sentence = "This is an example sentence! It contains words and non-word characters."

result = re.findall(regex_pattern, sentence)

print(result)
# Out:
# ['This', ' ', 'is', ' ', 'an', ' ', 'example', ' ', 'sentence', '!', ' ', 'It', ' ', 'contains', ' ', 'words', ' ', 'and', ' ', 'non', '-', 'word', ' ', 'characters', '.']

# %%
test_input = {'filename': 'Clonazepam_ddi',
  'sentence': 'Pharmacodynamic Interactions: The CNS-depressant action of the benzodiazepine class of drugs may be potentiated by alcohol, narcotics, barbiturates, nonbarbiturate hypnotics, antianxiety agents, the phenothiazines, thioxanthene and butyrophenone classes of antipsychotic agents, monoamine oxidase inhibitors and the tricyclic antidepressants, and by other anticonvulsant drugs.',
  'sent_id': 'DDI-DrugBank.d333.s7',
  'entity1': {'text': 'nonbarbiturate hypnotics',
   'type': 'group',
   'char_offset': [(149, 172)]},
  'entity2': {'text': 'anticonvulsant drugs',
   'type': 'group',
   'char_offset': [(356, 375)]},
  'ddi': False,
  'type': 'unknown',
  'all_ents': {'DDI-DrugBank.d333.s7.e0': {'text': 'benzodiazepine class',
    'type': 'group',
    'char_offset': [(63, 82)]},
   'DDI-DrugBank.d333.s7.e1': {'text': 'alcohol',
    'type': 'drug',
    'char_offset': [(115, 121)]},
   'DDI-DrugBank.d333.s7.e2': {'text': 'narcotics',
    'type': 'group',
    'char_offset': [(124, 132)]},
   'DDI-DrugBank.d333.s7.e3': {'text': 'barbiturates',
    'type': 'group',
    'char_offset': [(135, 146)]},
   'DDI-DrugBank.d333.s7.e4': {'text': 'nonbarbiturate hypnotics',
    'type': 'group',
    'char_offset': [(149, 172)]},
   'DDI-DrugBank.d333.s7.e5': {'text': 'antianxiety agents',
    'type': 'group',
    'char_offset': [(175, 192)]},
   'DDI-DrugBank.d333.s7.e6': {'text': 'phenothiazines classes of antipsychotic agents',
    'type': 'group',
    'char_offset': [(199, 212), (246, 276)]},
   'DDI-DrugBank.d333.s7.e7': {'text': 'thioxanthene classes of antipsychotic agents',
    'type': 'group',
    'char_offset': [(215, 226), (246, 276)]},
   'DDI-DrugBank.d333.s7.e8': {'text': 'butyrophenone classes of antipsychotic agents',
    'type': 'group',
    'char_offset': [(232, 276)]},
   'DDI-DrugBank.d333.s7.e9': {'text': 'monoamine oxidase inhibitors',
    'type': 'group',
    'char_offset': [(279, 306)]},
   'DDI-DrugBank.d333.s7.e10': {'text': 'tricyclic antidepressants',
    'type': 'group',
    'char_offset': [(316, 340)]},
   'DDI-DrugBank.d333.s7.e11': {'text': 'anticonvulsant drugs',
    'type': 'group',
    'char_offset': [(356, 375)]}}}

# %%
preprocess_for_transformer([{'filename': 'Hydrochlorothiazide_ddi',
  'sentence': 'Non-steroidal Anti-inflammatory Drugs: In some patients, the administration of a non-steroidal anti-inflammatory agent can reduce the diuretic, natriuretic, and antihypertensive effects of loop, potassium-sparing and thiazide diuretics.',
  'sent_id': 'DDI-DrugBank.d162.s12',
  'entity1': {'text': 'loop diuretics',
   'type': 'group',
   'char_offset': [(189, 192), (226, 234)]},
  'entity2': {'text': 'thiazide diuretics',
   'type': 'group',
   'char_offset': [(217, 234)]},
  'ddi': False,
  'type': 'unknown'}])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-134-e6b6f909b426> in <module>
# ----> 1 preprocess_for_transformer([{'filename': 'Hydrochlorothiazide_ddi',
#       2   'sentence': 'Non-steroidal Anti-inflammatory Drugs: In some patients, the administration of a non-steroidal anti-inflammatory agent can reduce the diuretic, natriuretic, and antihypertensive effects of loop, potassium-sparing and thiazide diuretics.',
#       3   'sent_id': 'DDI-DrugBank.d162.s12',
#       4   'entity1': {'text': 'loop diuretics',
#       5    'type': 'group',
#
# <ipython-input-133-978d9297386d> in preprocess_for_transformer(data)
#     232                     else:
#     233                         labels[i] = f'I-{entity_type}'
# --> 234         input_examples.append(InputExample(guid=instance['sent_id'], text_a=sentence, label=label, data={'entities': entities}))
#     235     return input_examples
#
# TypeError: __init__() got an unexpected keyword argument 'data'

# %%
filenames = []
sentences = []
entity1 = []
entity2 = []
for file in train_data:
    filenames.append(file['filename'])
    sentences.append(file['sentence'])
    entity1.append(file['entity1'])
    entity2.append(file['entity2'])
    
for file in val_data:
    filenames.append(file['filename'])
    sentences.append(file['sentence'])
    entity1.append(file['entity1'])
    entity2.append(file['entity2'])
    
# for file in test_data:
#     filenames.append(file['filename'])
#     sentences.append(file['sentence'])
#     entity1.append(file['entity1'])
#     entity2.append(file['entity2'])

# %%
df = pd.DataFrame({
    'filename':filenames,
    'sentence':sentences,
    'ent_1':entity1,

    'ent_2':entity2,

    })

# %%
df[['ent_1_text', 'ent_1_type', 'ent_1_offset']] = df['ent_1'].apply(lambda x: extract_entity_info(x))
df[['ent_2_text', 'ent_2_type', 'ent_2_offset']] = df['ent_2'].apply(lambda x: extract_entity_info(x))

# %%
df[['ent_1_type', 'ent_2_type']].value_counts()
# Out:
# ent_1_type  ent_2_type
# drug        drug          13043
# group       drug           3646
#             group          2961
# drug        group          2900
# brand       drug           1479
# drug        brand          1162
# brand       brand           802
# group       brand           487
# brand       group           472
# drug        drug_n          288
# drug_n      drug_n          234
#             drug            224
# group       drug_n           40
# drug_n      group            39
# brand       drug_n           10
# drug_n      brand             5
# dtype: int64

# %%
df[df['ent_1_offset'].apply(len) > 1]
# Out:
#                       filename  \
# 782    Hydrochlorothiazide_ddi
# 935           Indomethacin_ddi
# 2670            Clonazepam_ddi
# 2882            Clonazepam_ddi
# 3456                  11121884
# ...                        ...
# 24561        Dexamethasone_ddi
# 24687           Dofetilide_ddi
# 25933           Clonazepam_ddi
# 26942   Hydroflumethiazide_ddi
# 27293         Lenalidomide_ddi
#
#                                                 sentence  \
# 782    Non-steroidal Anti-inflammatory Drugs: In some...
# 935    In some patients, the administration of INDOCI...
# 2670   Pharmacodynamic Interactions: The CNS-depressa...
# 2882   Pharmacodynamic Interactions: The CNS-depressa...
# 3456   The percentage of neurons hyperpolarized by mu...
# ...                                                  ...
# 24561  Vaccines: Patients on corticosteroid therapy m...
# 24687  If a patient requires TIKOSYN and anti-ulcer t...
# 25933  Pharmacodynamic Interactions: The CNS-depressa...
# 26942  (In some patients, the steroidal anti-inflamma...
# 27293  Co-administration of multiple doses of 10 mg o...
#
#                                                    ent_1  \
# 782    {'text': 'loop diuretics', 'type': 'group', 'c...
# 935    {'text': 'loop diuretics', 'type': 'group', 'c...
# 2670   {'text': 'phenothiazines classes of antipsycho...
# 2882   {'text': 'thioxanthene classes of antipsychoti...
# 3456   {'text': 'mu-selective opioids', 'type': 'grou...
# ...                                                  ...
# 24561  {'text': 'live vaccines', 'type': 'group', 'ch...
# 24687  {'text': 'aluminum hydroxide', 'type': 'drug',...
# 25933  {'text': 'phenothiazines classes of antipsycho...
# 26942  {'text': 'loop diuretics', 'type': 'group', 'c...
# 27293  {'text': 'R- warfarin', 'type': 'drug', 'char_...
#
#                                                    ent_2  \
# 782    {'text': 'thiazide diuretics', 'type': 'group'...
# 935    {'text': 'potassium-sparing diuretics', 'type'...
# 2670   {'text': 'tricyclic antidepressants', 'type': ...
# 2882   {'text': 'monoamine oxidase inhibitors', 'type...
# 3456   {'text': 'delta(1)-selective opioids', 'type':...
# ...                                                  ...
# 24561  {'text': 'inactivated vaccines', 'type': 'grou...
# 24687  {'text': 'magnesium hydroxide', 'type': 'drug'...
# 25933  {'text': 'butyrophenone classes of antipsychot...
# 26942  {'text': 'thiazide diuretics', 'type': 'group'...
# 27293  {'text': 'S- warfarin', 'type': 'drug', 'char_...
#
#                                            ent_1_text ent_1_type  \
# 782                                    loop diuretics      group
# 935                                    loop diuretics      group
# 2670   phenothiazines classes of antipsychotic agents      group
# 2882     thioxanthene classes of antipsychotic agents      group
# 3456                             mu-selective opioids      group
# ...                                               ...        ...
# 24561                                   live vaccines      group
# 24687                              aluminum hydroxide       drug
# 25933  phenothiazines classes of antipsychotic agents      group
# 26942                                  loop diuretics      group
# 27293                                     R- warfarin       drug
#
#                    ent_1_offset  \
# 782    [(189, 192), (226, 234)]
# 935    [(118, 121), (156, 164)]
# 2670   [(199, 212), (246, 276)]
# 2882   [(215, 226), (246, 276)]
# 3456       [(44, 46), (70, 86)]
# ...                         ...
# 24561    [(94, 97), (114, 121)]
# 24687  [(112, 119), (135, 143)]
# 25933  [(199, 212), (246, 276)]
# 26942  [(127, 130), (165, 173)]
# 27293  [(114, 115), (124, 131)]
#
#                                           ent_2_text ent_2_type  \
# 782                               thiazide diuretics      group
# 935                      potassium-sparing diuretics      group
# 2670                       tricyclic antidepressants      group
# 2882                    monoamine oxidase inhibitors      group
# 3456                      delta(1)-selective opioids      group
# ...                                              ...        ...
# 24561                           inactivated vaccines      group
# 24687                            magnesium hydroxide       drug
# 25933  butyrophenone classes of antipsychotic agents      group
# 26942                             thiazide diuretics      group
# 27293                                    S- warfarin       drug
#
#                    ent_2_offset
# 782                [(217, 234)]
# 935    [(124, 140), (156, 164)]
# 2670               [(316, 340)]
# 2882               [(279, 306)]
# 3456       [(49, 57), (70, 86)]
# ...                         ...
# 24561              [(102, 121)]
# 24687              [(125, 143)]
# 25933              [(232, 276)]
# 26942              [(156, 173)]
# 27293              [(121, 131)]
#
# [68 rows x 10 columns]

# %%
df['ent_2_offset'].str.split('-')
# Out:
# 0          [70, 73]
# 1        [326, 342]
# 2          [34, 45]
# 3        [413, 423]
# 4          [73, 80]
#             ...
# 28728    [134, 138]
# 28729    [134, 138]
# 28730      [39, 43]
# 28731      [46, 49]
# 28732      [46, 49]
# Name: ent_2_offset, Length: 28733, dtype: object

# %%
# Convert list of dictionaries to DataFrame
df = pd.DataFrame(train_data)

# Flatten entity1 and entity2 dictionaries
df = pd.concat([df.drop(['entity1'], axis=1), df['entity1'].apply(pd.Series)], axis=1)
df = pd.concat([df.drop(['entity2'], axis=1), df['entity2'].apply(pd.Series)], axis=1)

# Reorder columns
df = df[['filename', 'sentence', 'text_x', 'type_x', 'char_offset_x', 'text_y', 'type_y', 'char_offset_y', 'ddi', 'type']]
df.columns = ['filename', 'sentence', 'entity1', 'entity1_type', 'entity1_char_offset', 'entity2', 'entity2_type', 'entity2_char_offset', 'ddi', 'ddi_type']

# Print DataFrame
print(df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-25216040f182> in <module>
#       7
#       8 # Reorder columns
# ----> 9 df = df[['filename', 'sentence', 'text_x', 'type_x', 'char_offset_x', 'text_y', 'type_y', 'char_offset_y', 'ddi', 'type']]
#      10 df.columns = ['filename', 'sentence', 'entity1', 'entity1_type', 'entity1_char_offset', 'entity2', 'entity2_type', 'entity2_char_offset', 'ddi', 'ddi_type']
#      11
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3811             if is_iterator(key):
#    3812                 key = list(key)
# -> 3813             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3814
#    3815         # take() does not accept boolean indexers
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    6068             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    6069
# -> 6070         self._raise_if_missing(keyarr, indexer, axis_name)
#    6071
#    6072         keyarr = self.take(indexer)
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/indexes/base.py in _raise_if_missing(self, key, indexer, axis_name)
#    6131
#    6132             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6133             raise KeyError(f"{not_found} not in index")
#    6134
#    6135     @overload
#
# KeyError: "['text_x', 'type_x', 'char_offset_x', 'text_y', 'type_y', 'char_offset_y'] not in index"
